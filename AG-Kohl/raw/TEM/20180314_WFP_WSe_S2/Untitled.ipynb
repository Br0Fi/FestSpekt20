# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import scipy
import pylab

# %%
data= np.loadtxt('WSe_S2_eels_zeroloss_010.txt')
#print(len(data), np.arange(4))

plt.plot(np.arange(len(data)), data)
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
