# %%
# Importanweisungen
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.axes as axes
from matplotlib import colors as mcolors
import matplotlib.patches as mpatches
import itertools
import math
import numpy as np
import statistics as stat
import scipy as sci
from scipy import optimize
import uncertainties as unc
import uncertainties.unumpy as unp
import uncertainties.umath as umath
import pandas as pd

unv=unp.nominal_values
usd=unp.std_devs

# %%
# Konstanten fuer einheitliche Darstellung

sidescreen = (8, 6)
fullscreen = (10,6)
widescreen = (16,6)
fig_size = fullscreen
fig_legendsize = 14
fig_labelsize = 12
matplotlib.rcParams.update({'font.size': fig_labelsize})

colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)

# %%
# allgemeine Fitfunktionen

def const(x,c):
    return c

def linear(x,m): # lineare Funktion mit f(x) = m * x 
    return(m*x)

def gerade(x, m, b): # gerade mit = f(x) = m * x + b
    return (m*x + b)

def cyclic(x, a, f, phi):
    return a * np.sin(x * f - phi)

def cyclicOff(x, a, f, phi, offset):
    return cyclic(x, a, f, phi) + offset

def gaussOff(x, x0, A, d, y0):
    return A * np.exp(-(x - x0)**2 / 2 / d**2) + y0

def gauss(x, A, x0, d):
    return A * np.exp(-(x-x0)**2 / 2 / d**2)

def exponential(x, c, y0):
    return np.exp(c * x) * y0

def ausbreitung(x, x0, A, g):
    return A / (x-x0)**g

# fittet ein dataset mit gegebenen x und y werten, eine funktion und ggf. anfangswerten und y-Fehler
# gibt die passenden parameter der funktion, sowie dessen unsicherheiten zurueck
#
# https://stackoverflow.com/questions/14581358/getting-standard-errors-on-fitted-parameters-using-the-optimize-leastsq-method-i#
# Updated on 4/6/2016
# User: https://stackoverflow.com/users/1476240/pedro-m-duarte
def fit_curvefit(datax, datay, function, p0=None, yerr=None, **kwargs):
    pfit, pcov = \
         optimize.curve_fit(function,datax,datay,p0=p0,\
                            sigma=yerr, epsfcn=0.0001, **kwargs)
    error = [] 
    for i in range(len(pfit)):
        try:
          error.append(np.absolute(pcov[i][i])**0.5)
        except:
          error.append( 0.00 )
    pfit_curvefit = pfit
    perr_curvefit = np.array(error)
    return pfit_curvefit, perr_curvefit

# usage zB:
# p = fit_curvefit(unv(xdata), unv(ydata), gerade, yerr = usd(ydata), p0 = [1, 0])
# fuer eine gerade mit anfangswerten m = 1, b = 0

# %%
# gibt Daten fuer LaTeX bereitgestellt aus

def latex_printValue(val, file):
    if hasattr(val, "__iter__"):
        i = 1
        for v in val:
            latex_printValue(v, file+"_"+str(i))
            i += 1
    else:
        f = open('data/%s.txt' % file, 'w')
        f.write(str(val).replace('/', ''))
                
def latex_printSI(val, unit, file):
    if hasattr(val, "__iter__"):
        i = 1
        for v in val:
            latex_printSI(v, unit, file+"_"+str(i))
            i += 1
    else:
        latex_printSIone(val, unit, file)

def latex_printSIone(val, unit, file):
    f = open('data/SI%s.txt' % file, 'w')
    f.write("\\SI{%s}{%s}" % (str(val).replace('/', '').replace('(', '').replace(')', ''), unit))
    
def print_latex(df):
    out="\\begin{tabular}{" + " | ".join(["r"] * len(df.columns)) + "}\n"
    out=out+" & ".join(df.keys())+"\\\\ \\hline \n"
    for i, row in df.iterrows():
        out=out+" & ".join(["$"+str(x)+"$" for x in row.values]) + " \\\\\n"
    out=out+"\\end{tabular}"
    out=out.replace("+/-","\\pm").replace(".",",").replace("$$","$")
    return out

# %%
# weitere Werte, Konstanten
# Werte von https://physics.nist.gov/cuu/Constants/index.html[0]

c = 299792458 # m/s
k_B = unc.ufloat_fromstr("1.38064852(79)e-23") # J K-1 [0]
h = unc.ufloat_fromstr("4.135667662(25)e-15") # eV s [0]
r_e = unc.ufloat_fromstr("2.8179403227(19)e-15") # m [0]
R = unc.ufloat_fromstr("8.3144598(48)") # J mol-1 K-1 [0]
K = 273.15 # kelvin 
eps_0 = 8.854187817e-12 # F m-1 = s4 A2 m-3 kg-1
F = 96485.33289 # Faraday konstante; coulomb per mol
Av = 6.02214076e23 # Avogadro-Konstante; n per 1 mol
g = 9.81 # m/s^2
rad = 360 / 2 / math.pi
grad = 1/rad
terra = 1e12
giga = 1e9
mega = 1e6
kilo = 1e3
dezi = 0.1
centi = 0.01
milli = 1e-3
micro = 1e-6
nano = 1e-9
pico = 1e-12
femto = 1e-15

# %%
# import der daten

uncE = 20.4689/4096 * 1/(2*np.sqrt(2))

data = np.loadtxt("../raw/SEM/Kupferprobe.csv", unpack=True, delimiter=",", skiprows=0)
energyCu = np.array(data[0])
countsCu = np.array(data[1])
xdataCu = unp.uarray(energyCu,uncE)
ydataCu = unp.uarray(countsCu,np.sqrt(countsCu)+1e-15)

data = np.loadtxt("../raw/SEM/Zinkprobe.csv", unpack=True, delimiter=",", skiprows=0)
energyZn = np.array(data[0])
countsZn = np.array(data[1])
xdataZn = unp.uarray(energyZn,uncE)
ydataZn = unp.uarray(countsZn,np.sqrt(countsZn)+1e-15)

data = np.loadtxt("../raw/SEM/Messingprobe.csv", unpack=True, delimiter=",", skiprows=0)
energyMs = np.array(data[0])
countsMs = np.array(data[1])
xdataMs = unp.uarray(energyMs,uncE)
ydataMs = unp.uarray(countsMs,np.sqrt(countsMs)+1e-15)

print(unv(xdataCu))
print(unv(ydataCu))
print(usd(ydataCu))
# Out:
# [-0.4755 -0.4705 -0.4655 ... 19.9834 19.9884 19.9934]
# [ 0.  0.  0. ... 17. 16. 10.]
# [1.00000000e-15 1.00000000e-15 1.00000000e-15 ... 4.12310563e+00
#  4.00000000e+00 3.16227766e+00]

# %%
#setup

fig=plt.figure(figsize=fullscreen)
ax = plt.gca()

#Datenpunkte
plt.errorbar(unv(xdataCu), unv(ydataCu), usd(ydataCu), usd(xdataCu), color="g", label="Kupferprobe", ls=" ",marker=".",markersize="1")
plt.errorbar(unv(xdataZn), unv(ydataZn), usd(ydataZn), usd(xdataZn), color="b", label="Zinkprobe", ls=" ",marker=".",markersize="1")
plt.errorbar(unv(xdataMs), unv(ydataMs), usd(ydataMs), usd(xdataMs), color="r", label="Messingprobe", ls=" ",marker=".",markersize="1")

# Kupfer K-Alpha
pfit, perr = fit_curvefit(unv(xdataCu), unv(ydataCu), gauss, yerr = usd(ydataCu), p0 = [1e4,8.046,0.1])
l1 = unp.uarray(pfit, perr)
xfit = np.linspace(7, 10, 1000)
yfit = gauss(xfit, *unv(l1))
plt.plot(xfit, unv(yfit) , linewidth = 1, color = "y", label="Gaußfits - Kupferprobe")
amplitudeCuKA = l1[0]

# Kupfer K-Beta
pfit, perr = fit_curvefit(unv(xdataCu), unv(ydataCu), gauss, yerr = usd(ydataCu), p0 = [1200,8.904,0.1])
l1 = unp.uarray(pfit, perr)
xfit = np.linspace(7, 10, 1000)
yfit = gauss(xfit, *unv(l1))
plt.plot(xfit, unv(yfit) , linewidth = 1, color = "y")
amplitudeCuKB = l1[0]

# Zink K-Alpha
pfit, perr = fit_curvefit(unv(xdataZn), unv(ydataZn), gauss, yerr = usd(ydataZn), p0 = [8e3,8.637,0.1])
l1 = unp.uarray(pfit, perr)
xfit = np.linspace(7, 10, 1000)
yfit = gauss(xfit, *unv(l1))
plt.plot(xfit, unv(yfit) , linewidth = 1, color = "c", label="Gaußfits - Zinkprobe")
amplitudeZnKA = l1[0]

# Zink K-Beta
pfit, perr = fit_curvefit(unv(xdataZn), unv(ydataZn), gauss, yerr = usd(ydataZn), p0 = [1200,9.570,0.1])
l1 = unp.uarray(pfit, perr)
xfit = np.linspace(7, 10, 1000)
yfit = gauss(xfit, *unv(l1))
plt.plot(xfit, unv(yfit) , linewidth = 1, color = "c")
amplitudeZnKB = l1[0]

# Messing Cu-K-Alpha
pfit, perr = fit_curvefit(unv(xdataMs), unv(ydataMs), gauss, yerr = usd(ydataMs), p0 = [6e3,8.046,0.1])
l1 = unp.uarray(pfit, perr)
xfit = np.linspace(7, 10, 1000)
yfit = gauss(xfit, *unv(l1))
plt.plot(xfit, unv(yfit) , linewidth = 1, color = "m",label="Gaußfits - Messingprobe")
amplitudeMsCuKA = l1[0]

# Messing Cu-K-Beta
xdataMs_extracted = unv(xdataMs)[1865:1993]
ydataMs_extracted = unv(ydataMs)[1865:1993]
ydataMs_extracted2 = usd(ydataMs)[1865:1993]

pfit, perr = fit_curvefit(xdataMs_extracted, ydataMs_extracted, gauss, yerr = ydataMs_extracted2, p0 = [1000,8.904,0.1])
l1 = unp.uarray(pfit, perr)
xfit = np.linspace(7, 10, 1000)
yfit = gauss(xfit, *unv(l1))
plt.plot(xfit, unv(yfit) , linewidth = 1, color = "m")
amplitudeMsCuKB = l1[0]

# Messing Zn-K-Alpha
pfit, perr = fit_curvefit(unv(xdataMs), unv(ydataMs), gauss, yerr = usd(ydataMs), p0 = [3500,8.637,0.1])
l1 = unp.uarray(pfit, perr)
xfit = np.linspace(7, 10, 1000)
yfit = gauss(xfit, *unv(l1))
plt.plot(xfit, unv(yfit) , linewidth = 1, color = "m")
amplitudeMsZnKA = l1[0]

# Messing Zn-K-Beta
xdataMs_extracted = unv(xdataMs)[1993:2097]
ydataMs_extracted = unv(ydataMs)[1993:2097]
ydataMs_extracted2 = usd(ydataMs)[1993:2097]

pfit, perr = fit_curvefit(xdataMs_extracted, ydataMs_extracted, gauss, yerr = ydataMs_extracted2, p0 = [500,9.570,0.1])
l1 = unp.uarray(pfit, perr)
xfit = np.linspace(7, 10, 1000)
yfit = gauss(xfit, *unv(l1))
plt.plot(xfit, unv(yfit) , linewidth = 1, color = "m")
amplitudeMsZnKB = l1[0]

# fig param

plt.grid()
plt.xlabel("Energie (keV)")
plt.ylabel("Anzahl")
#plt.xlim(-0.5, 12.5)
plt.xlim(7, 10)
plt.ylim(0,10000)
plt.legend(prop={'size':fig_legendsize})
plt.tick_params(labelsize=fig_labelsize)
plt.savefig("../plots/KupferprobeK.pdf")
plt.show()

# %%
#setup

fig=plt.figure(figsize=fullscreen)
ax = plt.gca()

plt.errorbar(unv(xdataCu), unv(ydataCu), usd(ydataCu), usd(xdataCu), color="g", label="Kupferprobe", ls=" ",marker=".",markersize="1")
plt.errorbar(unv(xdataZn), unv(ydataZn), usd(ydataZn), usd(xdataZn), color="b", label="Zinkprobe", ls=" ",marker=".",markersize="1")
plt.errorbar(unv(xdataMs), unv(ydataMs), usd(ydataMs), usd(xdataMs), color="r", label="Messingprobe", ls=" ",marker=".",markersize="1")

plt.grid()
plt.xlabel("Energie (keV)")
plt.ylabel("Anzahl")
plt.xlim(-0.4, 20)
#plt.xlim(7, 10)
#plt.ylim(0,10000)
plt.legend(prop={'size':fig_legendsize})
plt.tick_params(labelsize=fig_labelsize)
plt.savefig("../plots/KupferprobeGanz.pdf")
plt.show()

# %%
#setup

fig=plt.figure(figsize=fullscreen)
ax = plt.gca()

plt.errorbar(unv(xdataCu), unv(ydataCu), usd(ydataCu), usd(xdataCu), color="g", label="Kupferprobe", ls=" ",marker=".",markersize="1")
plt.errorbar(unv(xdataZn), unv(ydataZn), usd(ydataZn), usd(xdataZn), color="b", label="Zinkprobe", ls=" ",marker=".",markersize="1")
plt.errorbar(unv(xdataMs), unv(ydataMs), usd(ydataMs), usd(xdataMs), color="r", label="Messingprobe", ls=" ",marker=".",markersize="1")

plt.grid()
plt.xlabel("Energie (keV)")
plt.ylabel("Anzahl")
plt.xlim(0.8, 1.2)
#plt.xlim(7, 10)
#plt.ylim(0,10000)
plt.legend(prop={'size':fig_legendsize})
plt.tick_params(labelsize=fig_labelsize)
plt.savefig("../plots/KupferprobeL.pdf")
plt.show()

# %%
#print(amplitudeCuKA)
#print(amplitudeCuKB)
#print(amplitudeZnKA)
#print(amplitudeZnKB)
#print(amplitudeMsCuKA)
#print(amplitudeMsCuKB)
#print(amplitudeMsZnKA)
#print(amplitudeMsZnKA)

relativeValCuKA = amplitudeMsCuKA/amplitudeCuKA
relativeValZnKA = amplitudeMsZnKA/amplitudeZnKA

relativeValCuKB = amplitudeMsCuKB/amplitudeCuKB
relativeValZnKB = amplitudeMsZnKB/amplitudeZnKB

relativeValCuGes = (relativeValCuKA +  relativeValCuKB) * 0.5
relativeValZnGes = (relativeValZnKA +  relativeValZnKB) * 0.5

print("Kupfer")
print(" K-Alpha:\t",relativeValCuKA)
print(" K-Beta:\t",relativeValCuKB)
print(" Mittelwert:\t",relativeValCuGes)
print("Zink")
print(" K-Alpha:\t",relativeValZnKA)
print(" K-Beta:\t",relativeValZnKB)
print(" Mittelwert:\t",relativeValZnGes)
# Out:
# Kupfer
#  K-Alpha:	 0.626+/-0.035
#  K-Beta:	 0.73+/-0.09
#  Mittelwert:	 0.68+/-0.05
# Zink
#  K-Alpha:	 0.388+/-0.028
#  K-Beta:	 0.34+/-0.04
#  Mittelwert:	 0.362+/-0.025
